# %%
def pizza(size,*toppings):
    print(f"(size).inch pizza with:")
    for topping in toppings:
        print(f"-{topping}")

# %%
pizza(12,'pineapple')
# Out:
# (size).inch pizza with:
# -pineapple
